# %% [markdown]
# # MISSING VALUE

# %% [markdown]
# # import all libraries

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# Check the version of your PANDAS

# %%
pd.__version__
# Out:
# '1.1.3'

# %% [markdown]
# **NaN** = NaN stands for Not A Number and is one of the common ways to represent the missing value in the data. It is a special floating-point value and cannot be converted to any other type than float. NaN value is one of the major problems in Data Analysis.

# %% [markdown]
# ## **MISSING VALUE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A = pd.Series([2,4,6], index=[0,1,2])
B = pd.Series([1,3,5], index=[1,2,3])

# %%
A
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
B
# Out:
# 1    1
# 2    3
# 3    5
# dtype: int64

# %%
A + B
# Out:
# 0    NaN
# 1    5.0
# 2    9.0
# 3    NaN
# dtype: float64

# %%
A.add(B, fill_value = 0)
# Out:
# 0    2.0
# 1    5.0
# 2    9.0
# 3    5.0
# dtype: float64
